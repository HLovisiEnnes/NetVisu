# %%
import NetVisu
import gudhi
import matplotlib.pyplot as plt

# %% [markdown]
# # 2 entangled circles

# %%
data, target = NetVisu.datasets.entangled_two_circles(200, True)

model_relu = NetVisu.feedforward(4, 15, 'relu')
NetVisu.trains_network(model_relu, 100, data, target, verbose = 0, plot = True)
# Out:
# 13/13 [==============================] - 0s 750us/step - loss: 0.0029 - accuracy: 1.0000

# %%
model_relu.evaluate(data, target)
# Out:
# 13/13 [==============================] - 0s 887us/step - loss: 0.0029 - accuracy: 1.0000
# [0.002908495021983981, 1.0]

# %%
NetVisu.pca_network(5, 15, 'relu', data, target)
# Out:
# 13/13 [==============================] - 0s 890us/step - loss: 1.6038e-04 - accuracy: 1.0000

# %%
NetVisu.persistence_homology(data)
# Out:
# usetex mode requires TeX.

# %%
NetVisu.persis_homol_network(5, 15, 'relu', data, target)
# Out:
# 13/13 [==============================] - 0s 666us/step - loss: 2.3311e-04 - accuracy: 1.0000

# %%
NetVisu.pca_and_persistence(5, 15, 'relu', data, target)
# Out:
# 13/13 [==============================] - 0s 667us/step - loss: 3.2247e-04 - accuracy: 1.0000

# %% [markdown]
# #  4 entangled circles

# %%
data, target = NetVisu.datasets.entangled_four_circles(200, True)

model_relu = NetVisu.feedforward(4, 15, 'relu')
NetVisu.trains_network(model_relu, 100, data, target, verbose = 0, plot = True)
# Out:
# 25/25 [==============================] - 0s 918us/step - loss: 0.0321 - accuracy: 0.9950

# %%
model_relu.evaluate(data, target)
# Out:
# 25/25 [==============================] - 0s 920us/step - loss: 0.0321 - accuracy: 0.9950
# [0.03209061175584793, 0.9950000047683716]

# %%
# %matplotlib inline

# %%
NetVisu.pca_network(5, 15, 'relu', data, target)
# Out:
# 25/25 [==============================] - 0s 917us/step - loss: 0.0231 - accuracy: 0.9975

# %%
NetVisu.persistence_homology(data)

# %%
NetVisu.persis_homol_network(5, 15, 'relu', data, target)
# Out:
# 25/25 [==============================] - 0s 958us/step - loss: 0.0244 - accuracy: 0.9950

# %%
NetVisu.pca_and_persistence(5, 15, 'relu', data, target)
# Out:
# 25/25 [==============================] - 0s 1ms/step - loss: 0.0278 - accuracy: 0.9950

# %% [markdown]
# # Circle inside a torus

# %%
data, target = NetVisu.datasets.circle_inside_torus(200, True)

model_relu = NetVisu.feedforward(4, 15, 'relu')
NetVisu.trains_network(model_relu, 1000, data, target, verbose = 0, plot = True)
# Out:
# 10/10 [==============================] - 0s 1ms/step - loss: 0.0789 - accuracy: 0.9933

# %%
NetVisu.persistence_homology(data, pers_dis = 2, intrinsic_dimension = 3)

# %%
NetVisu.pca_and_persistence(4, 15, 'relu', data, target, pers_dis = 2, intrinsic_dimension = 3)
# Out:
# 10/10 [==============================] - 0s 838us/step - loss: 0.0359 - accuracy: 0.9933

# %% [markdown]
# # Swiss roll

# %%
# %matplotlib notebook

# %%
data, target = NetVisu.datasets.swiss_roll(1000, True)

model_relu = NetVisu.feedforward(4, 15, 'relu')
NetVisu.trains_network(model_relu, 100, data, target, verbose = 0, plot = True)
# Out:
# <img src="data:image/png;base64,..." width="648">
# 63/63 [==============================] - 0s 855us/step - loss: 0.0096 - accuracy: 0.9950
# <img src="data:image/png;base64,..." width="864">

# %%
NetVisu.pca_network(2, 15, 'relu', data, target)
# Out:
# 63/63 [==============================] - 0s 500us/step - loss: 0.0103 - accuracy: 0.9950
# <img src="data:image/png;base64,..." width="648">
# <img src="data:image/png;base64,..." width="648">
